# %%
import socket
import sqlite3
import configparser
import time
import signal
import sys

# Load configuration from a file
config = configparser.ConfigParser()
config.read('config.ini')

# Get the PiAware configuration parameters
piaware_ip = config.get('PiAware', 'IP')
piaware_port = config.getint('PiAware', 'Port')

# Create a SQLite database and define flight_data and navigation tables
def create_database():
    with sqlite3.connect('flight_data.db') as conn:
        cursor = conn.cursor()

        # Create the flight_data and navigation_data tables using a single loop
        for table_name in ['flight_data', 'navigation_data']:
            cursor.execute(f'''
                CREATE TABLE IF NOT EXISTS {table_name} (
                    id INTEGER PRIMARY KEY,
                    message_type TEXT,
                    aircraft_icao_id TEXT,
                    date TEXT,
                    timestamp TEXT,
                    altitude REAL,
                    latitude REAL,
                    longitude REAL,
                    speed REAL,
                    heading REAL
                )
            ''')

        conn.commit()

# Create the database and tables
create_database()

# Handle Ctrl+C to gracefully exit the program
def signal_handler(sig, frame):
    print("Exiting the program.")
    sys.exit(0)

# Create a function to handle the data stream and database operations
def data_stream_and_store():
    while True:
        try:
            # Connect to the SQLite database
            with sqlite3.connect('flight_data.db') as conn:
                cursor = conn.cursor()

                sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
                sock.settimeout(600)

                try:
                    sock.connect((piaware_ip, piaware_port))
                    print('Connection established')

                    while True:
                        data = sock.recv(4096)

                        if not data:
                            print("No data received.")
                            print('Restarting socket')
                            sock.close()
                            sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
                            sock.settimeout(600)
                            sock.connect((piaware_ip, piaware_port))
                            continue

                        data_str = data.decode('utf-8')
                        fields = data_str.split(',')

                        # Check for valid message type
                        if fields[0] == 'MSG' and (fields[1] == '3' or fields[1] == '4') and len(fields) > 20:
                            message_type = fields[0] + fields[1]
                            aircraft_icao_id, date, timestamp = fields[4], fields[6], fields[7]

                            if fields[1] == '3':
                                altitude, latitude, longitude = fields[11], fields[14], fields[15]
                                cursor.execute("INSERT INTO flight_data (message_type, aircraft_icao_id, date, timestamp, altitude, latitude, longitude) VALUES (?, ?, ?, ?, ?, ?, ?)",
                                               (message_type, aircraft_icao_id, date, timestamp, altitude, latitude, longitude))
                                print(f"Record added - Message Type: {message_type}, Aircraft: {aircraft_icao_id}, Altitude: {altitude}, Latitude: {latitude}, Longitude: {longitude}")
                            else:
                                speed, heading = fields[12], fields[13]
                                cursor.execute("INSERT INTO navigation_data (message_type, aircraft_icao_id, date, timestamp, speed, heading) VALUES (?, ?, ?, ?, ?, ?)",
                                               (message_type, aircraft_icao_id, date, timestamp, speed, heading))
                                print(f"Record added - Message Type: {message_type}, Aircraft: {aircraft_icao_id}, Speed: {speed}, Heading: {heading}")

                            conn.commit()
                            time.sleep(10)

                except socket.timeout:
                    print("Socket timeout, waiting for data...")
                    time.sleep(10)
                    print('Restarting socket')
                    sock.close()
                    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
                    sock.settimeout(600)
                    sock.connect((piaware_ip, piaware_port))
                except Exception as e:
                    print(f"Error: {e}")

        except Exception as e:
            print(f"Outer Error: {e}")


# Start the data stream and database operations
if __name__ == "__main__":
    # Register the signal handler for Ctrl+C
    signal.signal(signal.SIGINT, signal_handler)
    
    # Start the data stream and database operations
    data_stream_and_store()
# Out:
# Connection established
# Record added - Message Type: MSG4, Aircraft: A58672, Speed: 423, Heading: 206
# Exiting the program.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3516: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import socket
import time
import signal
import sys
import adsb_functions


#Handle Ctrl+C to gracefully exit the program
def signal_handler(sig, frame):
    print("Exiting the program.")
    sys.exit(0)

if __name__ == "__main__":
    # Register the signal handler for Ctrl+C
    signal.signal(signal.SIGINT, signal_handler)

    # Create the database and start the data stream and database operations
    create_database()
    data_stream_and_store()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 18
#      15 signal.signal(signal.SIGINT, signal_handler)
#      17 # Create the database and start the data stream and database operations
# ---> 18 create_database()
#      19 data_stream_and_store()
#
# NameError: name 'create_database' is not defined

# %%
import sqlite3
import socket
import configparser
import time

# Load configuration from a file
config = configparser.ConfigParser()
config.read('config.ini')

# Get the PiAware configuration parameters
piaware_ip = config.get('PiAware', 'IP')
piaware_port = config.getint('PiAware', 'Port')

# Create a SQLite database and define flight_data and navigation tables
def create_database():
    with sqlite3.connect('flight_data.db') as conn:
        cursor = conn.cursor()

        # Create the flight_data and navigation_data tables using a single loop
        for table_name in ['flight_data', 'navigation_data']:
            cursor.execute(f'''
                CREATE TABLE IF NOT EXISTS {table_name} (
                    id INTEGER PRIMARY KEY,
                    message_type TEXT,
                    aircraft_icao_id TEXT,
                    date TEXT,
                    timestamp TEXT,
                    altitude REAL,
                    latitude REAL,
                    longitude REAL,
                    speed REAL,
                    heading REAL
                )
            ''')

        conn.commit()

# Create a function to handle the data stream and database operations
def data_stream_and_store():
    while True:
        try:
            # Connect to the SQLite database
            with sqlite3.connect('flight_data.db') as conn:
                cursor = conn.cursor()

                sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
                sock.settimeout(600)

                try:
                    sock.connect((piaware_ip, piaware_port))
                    print('Connection established')

                    while True:
                        data = sock.recv(4096)

                        if not data:
                            print("No data received.")
                            print('Restarting socket')
                            sock.close()
                            sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
                            sock.settimeout(600)
                            sock.connect((piaware_ip, piaware_port))
                            continue

                        data_str = data.decode('utf-8')
                        fields = data_str.split(',')

                        # Check for valid message type
                        if fields[0] == 'MSG' and (fields[1] == '3' or fields[1] == '4') and len(fields) > 20:
                            message_type = fields[0] + fields[1]
                            aircraft_icao_id, date, timestamp = fields[4], fields[6], fields[7]

                            if fields[1] == '3':
                                altitude, latitude, longitude = fields[11], fields[14], fields[15]
                                cursor.execute("INSERT INTO flight_data (message_type, aircraft_icao_id, date, timestamp, altitude, latitude, longitude) VALUES (?, ?, ?, ?, ?, ?, ?)",
                                               (message_type, aircraft_icao_id, date, timestamp, altitude, latitude, longitude))
                                print(f"Record added - Message Type: {message_type}, Aircraft: {aircraft_icao_id}, Altitude: {altitude}, Latitude: {latitude}, Longitude: {longitude}")
                            else:
                                speed, heading = fields[12], fields[13]
                                cursor.execute("INSERT INTO navigation_data (message_type, aircraft_icao_id, date, timestamp, speed, heading) VALUES (?, ?, ?, ?, ?, ?)",
                                               (message_type, aircraft_icao_id, date, timestamp, speed, heading))
                                print(f"Record added - Message Type: {message_type}, Aircraft: {aircraft_icao_id}, Speed: {speed}, Heading: {heading}")

                            conn.commit()
                            time.sleep(10)

                except socket.timeout:
                    print("Socket timeout, waiting for data...")
                    time.sleep(10)
                    print('Restarting socket')
                    sock.close()
                    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
                    sock.settimeout(600)
                    sock.connect((piaware_ip, piaware_port))
                except Exception as e:
                    print(f"Error: {e}")

        except Exception as e:
            print(f"Outer Error: {e}")

# %%
import pandas as pd
import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect('flight_data.db')

# Execute an SQL query to select data from the flight_data table
query = 'SELECT * FROM flight_data'
df = pd.read_sql(query, conn)

# Close the database connection
conn.close()

# %%
df.shape
# Out:
# (3034, 8)

# %%
import numpy as np
df = df.replace('', np.nan)
df.dropna(inplace=True)

# %%
new_df = df.drop_duplicates(subset=['aircraft_icao_id','date'])
new_df = new_df.reset_index(drop=True)
new_df.shape
# Out:
# (564, 8)

# %%
new_df.head()
# Out:
#    id message_type aircraft_icao_id        date     timestamp  altitude  \
# 0   1         MSG3           A310BB  2023/10/21  00:42:56.675   33025.0
# 1   3         MSG3           A51B58  2023/10/21  00:43:07.598   19475.0
# 2   6         MSG3           ABBD73  2023/10/21  00:44:08.980   36000.0
# 3  10         MSG3           AA7A61  2023/10/21  00:46:43.895   19925.0
# 4  14         MSG3           A38237  2023/10/21  00:48:51.451    6075.0
#
#    latitude  longitude
# 0  38.34210  -89.66679
# 1  38.42478  -89.93286
# 2  38.44894  -89.69734
# 3  38.50447  -90.07356
# 4  38.67110  -90.00627

# %%
import os
os.listdir()
# Out:
# ['flight_map.html',
#  'Untitled1.ipynb',
#  'adsb_functions.py',
#  'Untitled.ipynb',
#  '__pycache__',
#  'config.ini',
#  'final_project.ipynb',
#  'flight_data.db',
#  '.ipynb_checkpoints']

# %%
import socket
import time
import signal
import sys
import adsb_functions


#Handle Ctrl+C to gracefully exit the program
def signal_handler(sig, frame):
    print("Exiting the program.")
    sys.exit(0)

if __name__ == "__main__":
    # Register the signal handler for Ctrl+C
    signal.signal(signal.SIGINT, signal_handler)

    # Create the database and start the data stream and database operations
    create_database()
    data_stream_and_store()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 18
#      15 signal.signal(signal.SIGINT, signal_handler)
#      17 # Create the database and start the data stream and database operations
# ---> 18 create_database()
#      19 data_stream_and_store()
#
# NameError: name 'create_database' is not defined

# %%
import socket
import sqlite3
import configparser
import time
import signal
import sys

# Load configuration from a file
config = configparser.ConfigParser()
config.read('config.ini')

# Get the PiAware configuration parameters
piaware_ip = config.get('PiAware', 'IP')
piaware_port = config.getint('PiAware', 'Port')

# Create a SQLite database and define flight_data and navigation table
def create_database():
    conn = sqlite3.connect('flight_data.db')  # Replace with the desired database name
    cursor = conn.cursor()

    # Create the flight_data table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS flight_data (
            id INTEGER PRIMARY KEY,
            message_type TEXT,
            aircraft_icao_id TEXT,
            date TEXT,
            timestamp TEXT,
            altitude REAL,
            latitude REAL,
            longitude REAL
        )
    ''')

    # Create the navigation_data table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS navigation_data (
            id INTEGER PRIMARY KEY,
            message_type TEXT,
            aircraft_icao_id TEXT,
            date TEXT,
            timestamp TEXT,
            speed REAL,
            heading REAL
        )
    ''')

    conn.commit()
    conn.close()

# Create the database and flight_data table
create_database()

# Handle Ctrl+C to gracefully exit the program
def signal_handler(signal, frame):
    print("Exiting the program.")
    sys.exit(0)

# Create a function to handle the data stream and database operations
def data_stream_and_store():
    while True:
        try:
            # Connect to the SQLite database
            conn = sqlite3.connect('flight_data.db')
            cursor = conn.cursor()

            sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
            sock.settimeout(600)

            try:
                sock.connect((piaware_ip, piaware_port))
                print('Connection established')

                while True:
                    try:
                        data = sock.recv(4096)
                        if not data:
                            print("No data received.")
                            print('Restarting socket')
                            sock.close()  # Close the existing socket
                            sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)  # Create a new socket
                            sock.settimeout(600)  # Set timeout for the new socket
                            sock.connect((piaware_ip, piaware_port))
                            continue  # Continue receiving data

                        data_str = data.decode('utf-8')
                        fields = data_str.split(',')

                        # Handle the case where the MSG message type is not 3 or 4
                        if not fields[0] == 'MSG' or not (fields[1] == '3' or fields[1] == '4'):
                            continue

                        # Insert the data into the correct table
                        if fields[1] == '3' and len(fields) > 20:
                            cursor.execute("INSERT INTO flight_data (message_type, aircraft_icao_id, date, timestamp, altitude, latitude, longitude) VALUES (?, ?, ?, ?, ?, ?, ?)",
                                           (fields[0] + fields[1], fields[4], fields[6], fields[7], fields[11], fields[14], fields[15]))
                            print(f"Record added - Message Type: {fields[0] + fields[1]}, Aircraft: {fields[4]}, Altitude: {fields[11]}, Latitude: {fields[14]}, Longitude: {fields[15]}")
                        elif fields[1] == '4' and len(fields) > 20:
                            cursor.execute("INSERT INTO navigation_data (message_type, aircraft_icao_id, date, timestamp, speed, heading) VALUES (?, ?, ?, ?, ?, ?)",
                                           (fields[0] + fields[1], fields[4], fields[6], fields[7], fields[12], fields[13]))
                            print(f"Record added - Message Type: {fields[0] + fields[1]}, Aircraft: {fields[4]}, Speed: {fields[12]}, Heading: {fields[13]}")

                        # Commit the changes to the database
                        conn.commit()
                        time.sleep(10)
                    except socket.timeout:
                        print("Socket timeout, waiting for data...")
                        time.sleep(10)
                        print('Restarting socket')
                        sock.close()  # Close the existing socket
                        sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)  # Create a new socket
                        sock.settimeout(600)  # Set timeout for the new socket
                        sock.connect((piaware_ip, piaware_port))
                    except Exception as e:
                        print(f"Error: {e}")
            except socket.error as e:
                print(f"Socket error: {e}")
            finally:
                cursor.close()
                conn.close()
                sock.close()
        except Exception as e:
            print(f"Outer Error: {e}")

# Start the data stream and database operations
if __name__ == "__main__":
    # Register the signal handler for Ctrl+C
    signal.signal(signal.SIGINT, signal_handler)
    
    # Start the data stream and database operations
    data_stream_and_store()
# Out:
# Connection established
# Record added - Message Type: MSG3, Aircraft: A58672, Altitude: 30000, Latitude: 38.52887, Longitude: -89.71039
# Record added - Message Type: MSG4, Aircraft: A7130C, Speed: 244, Heading: 354
# Record added - Message Type: MSG4, Aircraft: A7130C, Speed: 241, Heading: 354
# Record added - Message Type: MSG4, Aircraft: A7130C, Speed: 239, Heading: 354
# Record added - Message Type: MSG3, Aircraft: A7130C, Altitude: 4425, Latitude: 38.56911, Longitude: -90.06837
# Record added - Message Type: MSG4, Aircraft: A2B1AB, Speed: 511, Heading: 123
# Record added - Message Type: MSG3, Aircraft: A2B1AB, Altitude: 35000, Latitude: 38.48488, Longitude: -90.28164
# Record added - Message Type: MSG3, Aircraft: A7130C, Altitude: 3875, Latitude: 38.60139, Longitude: -90.08850
# Record added - Message Type: MSG3, Aircraft: A2B1AB, Altitude: 35000, Latitude: 38.45890, Longitude: -90.23041
# Record added - Message Type: MSG4, Aircraft: A2B1AB, Speed: 511, Heading: 123
# Record added - Message Type: MSG3, Aircraft: A2B1AB, Altitude: 35000, Latitude: 38.41988, Longitude: -90.15333
# Record added - Message Type: MSG4, Aircraft: A2B1AB, Speed: 512, Heading: 123
# Record added - Message Type: MSG4, Aircraft: A2B1AB, Speed: 513, Heading: 123
# Record added - Message Type: MSG3, Aircraft: A2B1AB, Altitude: 35000, Latitude: 38.37725, Longitude: -90.06950
# Record added - Message Type: MSG3, Aircraft: A2B1AB, Altitude: 35000, Latitude: 38.36467, Longitude: -90.04482
# Record added - Message Type: MSG4, Aircraft: A2B1AB, Speed: 513, Heading: 123
# Record added - Message Type: MSG4, Aircraft: A2B1AB, Speed: 513, Heading: 123
# Record added - Message Type: MSG4, Aircraft: A2B1AB, Speed: 513, Heading: 123
# Record added - Message Type: MSG4, Aircraft: A2B1AB, Speed: 514, Heading: 123
# Record added - Message Type: MSG3, Aircraft: A2B1AB, Altitude: 35000, Latitude: 38.30956, Longitude: -89.93659
# Record added - Message Type: MSG4, Aircraft: A2B1AB, Speed: 515, Heading: 123
# Record added - Message Type: MSG3, Aircraft: A2B1AB, Altitude: 35000, Latitude: 38.28296, Longitude: -89.88447
# Record added - Message Type: MSG3, Aircraft: AAAE1B, Altitude: 10800, Latitude: , Longitude:
# Record added - Message Type: MSG4, Aircraft: AAAE1B, Speed: 283, Heading: 224
# Record added - Message Type: MSG3, Aircraft: AAAE1B, Altitude: 10500, Latitude: 38.78920, Longitude: -89.85574
# Record added - Message Type: MSG4, Aircraft: A2B1AB, Speed: 517, Heading: 123
# Record added - Message Type: MSG4, Aircraft: AAAE1B, Speed: 262, Heading: 225
# Record added - Message Type: MSG3, Aircraft: A2B1AB, Altitude: 35000, Latitude: 38.18596, Longitude: -89.69495
# Record added - Message Type: MSG3, Aircraft: A2B1AB, Altitude: 35000, Latitude: 38.18471, Longitude: -89.69256
# Record added - Message Type: MSG4, Aircraft: AAAE1B, Speed: 257, Heading: 235
# Record added - Message Type: MSG3, Aircraft: AAAE1B, Altitude: 9125, Latitude: 38.74384, Longitude: -89.91886
# Record added - Message Type: MSG4, Aircraft: A2B1AB, Speed: 517, Heading: 123
# Record added - Message Type: MSG3, Aircraft: A2B1AB, Altitude: 35000, Latitude: 38.13075, Longitude: -89.58784
# Record added - Message Type: MSG4, Aircraft: A2B1AB, Speed: 516, Heading: 123
# Record added - Message Type: MSG4, Aircraft: AAAE1B, Speed: 224, Heading: 236
# Record added - Message Type: MSG3, Aircraft: AAAE1B, Altitude: 7825, Latitude: 38.70209, Longitude: -89.99839
# Record added - Message Type: MSG4, Aircraft: AAAE1B, Speed: 215, Heading: 236
# Record added - Message Type: MSG3, Aircraft: AAAE1B, Altitude: 7200, Latitude: 38.69344, Longitude: -90.01499
# Record added - Message Type: MSG3, Aircraft: AA6A98, Altitude: 40925, Latitude: , Longitude:
# Record added - Message Type: MSG3, Aircraft: AA6A98, Altitude: 40925, Latitude: 38.11958, Longitude: -89.66883
# Record added - Message Type: MSG4, Aircraft: A2B1AB, Speed: 502, Heading: 123
# Record added - Message Type: MSG3, Aircraft: A2B1AB, Altitude: 33925, Latitude: 38.00096, Longitude: -89.33718
# Record added - Message Type: MSG3, Aircraft: AAAE1B, Altitude: 5425, Latitude: 38.66277, Longitude: -90.07673
# Record added - Message Type: MSG4, Aircraft: AAAE1B, Speed: 207, Heading: 240
# Record added - Message Type: MSG3, Aircraft: AAAE1B, Altitude: 4550, Latitude: 38.66010, Longitude: -90.10626
# Record added - Message Type: MSG4, Aircraft: AAAE1B, Speed: 215, Heading: 273
# Record added - Message Type: MSG4, Aircraft: AA6A98, Speed: 557, Heading: 89
# Record added - Message Type: MSG3, Aircraft: AA6A98, Altitude: 40925, Latitude: , Longitude:
# Record added - Message Type: MSG4, Aircraft: AA6A98, Speed: 555, Heading: 89
# Record added - Message Type: MSG4, Aircraft: ABE579, Speed: 379, Heading: 360
# Record added - Message Type: MSG4, Aircraft: ABE579, Speed: 379, Heading: 360
# Record added - Message Type: MSG3, Aircraft: ABE579, Altitude: 13425, Latitude: , Longitude:
# Record added - Message Type: MSG4, Aircraft: ABE579, Speed: 364, Heading: 359
# Record added - Message Type: MSG3, Aircraft: ABE579, Altitude: 12950, Latitude: , Longitude:
# Record added - Message Type: MSG4, Aircraft: ABE579, Speed: 346, Heading: 359
# Record added - Message Type: MSG3, Aircraft: ABE579, Altitude: 12625, Latitude: 38.28489, Longitude: -90.04705
# Record added - Message Type: MSG3, Aircraft: ABE579, Altitude: 12375, Latitude: 38.30057, Longitude: -90.04729
# Record added - Message Type: MSG3, Aircraft: ABE579, Altitude: 12025, Latitude: 38.33074, Longitude: -90.04789
# Record added - Message Type: MSG3, Aircraft: ABE579, Altitude: 12000, Latitude: 38.33208, Longitude: -90.04792
# Record added - Message Type: MSG4, Aircraft: A29680, Speed: 511, Heading: 55
# Record added - Message Type: MSG3, Aircraft: A57F11, Altitude: 39000, Latitude: , Longitude:
# Record added - Message Type: MSG4, Aircraft: A57F11, Speed: 555, Heading: 95
# Record added - Message Type: MSG4, Aircraft: A29680, Speed: 514, Heading: 55
# Record added - Message Type: MSG4, Aircraft: AC9FF2, Speed: 311, Heading: 4
# Record added - Message Type: MSG4, Aircraft: AC9FF2, Speed: 305, Heading: 3
# Record added - Message Type: MSG4, Aircraft: AC9FF2, Speed: 305, Heading: 3
# Record added - Message Type: MSG3, Aircraft: AC9FF2, Altitude: 8525, Latitude: 38.45922, Longitude: -89.91187
# Record added - Message Type: MSG3, Aircraft: AC9FF2, Altitude: 8500, Latitude: 38.46057, Longitude: -89.91174
# Record added - Message Type: MSG4, Aircraft: A7BF58, Speed: 410, Heading: 205
# Record added - Message Type: MSG3, Aircraft: AC9FF2, Altitude: 7275, Latitude: 38.50014, Longitude: -89.91455
# Record added - Message Type: MSG3, Aircraft: AC9FF2, Altitude: 7250, Latitude: 38.50075, Longitude: -89.91486
# Record added - Message Type: MSG3, Aircraft: AC9FF2, Altitude: 6425, Latitude: 38.52081, Longitude: -89.93359
# Record added - Message Type: MSG3, Aircraft: A7BF58, Altitude: 36000, Latitude: 38.56937, Longitude: -89.90393
# Record added - Message Type: MSG4, Aircraft: AC9FF2, Speed: 264, Heading: 304
# Record added - Message Type: MSG4, Aircraft: AC9FF2, Speed: 264, Heading: 304
# Record added - Message Type: MSG3, Aircraft: A7BF58, Altitude: 35975, Latitude: 38.50127, Longitude: -89.94501
# Record added - Message Type: MSG3, Aircraft: AC9FF2, Altitude: 5725, Latitude: 38.55661, Longitude: -90.00018
# Record added - Message Type: MSG4, Aircraft: AC9FF2, Speed: 264, Heading: 303
# Record added - Message Type: MSG3, Aircraft: A7BF58, Altitude: 36000, Latitude: 38.44535, Longitude: -89.97864
# Record added - Message Type: MSG4, Aircraft: AC9FF2, Speed: 264, Heading: 302
# Record added - Message Type: MSG4, Aircraft: A7BF58, Speed: 409, Heading: 205
# Record added - Message Type: MSG4, Aircraft: A7BF58, Speed: 408, Heading: 205
# Record added - Message Type: MSG3, Aircraft: AC9FF2, Altitude: 5725, Latitude: 38.59200, Longitude: -90.07093
# Record added - Message Type: MSG4, Aircraft: AC9FF2, Speed: 263, Heading: 302
# Record added - Message Type: MSG4, Aircraft: AC9FF2, Speed: 263, Heading: 302
# Record added - Message Type: MSG4, Aircraft: AC9FF2, Speed: 251, Heading: 302
# Record added - Message Type: MSG3, Aircraft: AC9FF2, Altitude: 4850, Latitude: 38.62605, Longitude: -90.13954
# Record added - Message Type: MSG4, Aircraft: AC9FF2, Speed: 242, Heading: 302
# Record added - Message Type: MSG3, Aircraft: AC9FF2, Altitude: 4550, Latitude: 38.63324, Longitude: -90.15399
# Record added - Message Type: MSG4, Aircraft: AC9FF2, Speed: 229, Heading: 202
# Record added - Message Type: MSG4, Aircraft: 344346, Speed: 582, Heading: 57
# Record added - Message Type: MSG3, Aircraft: 344346, Altitude: 36975, Latitude: 38.15300, Longitude: -89.68899
# Record added - Message Type: MSG4, Aircraft: 344346, Speed: 583, Heading: 57
# Record added - Message Type: MSG4, Aircraft: 344346, Speed: 583, Heading: 57
# Record added - Message Type: MSG3, Aircraft: C001EA, Altitude: 43000, Latitude: 38.65823, Longitude: -89.92005
# Record added - Message Type: MSG4, Aircraft: C001EA, Speed: 377, Heading: 315
# Record added - Message Type: MSG4, Aircraft: A68336, Speed: 519, Heading: 131
# Record added - Message Type: MSG4, Aircraft: C001EA, Speed: 377, Heading: 315
# Record added - Message Type: MSG4, Aircraft: C001EA, Speed: 378, Heading: 315
# Record added - Message Type: MSG4, Aircraft: A68336, Speed: 520, Heading: 131
# Record added - Message Type: MSG3, Aircraft: A68336, Altitude: 39000, Latitude: 38.23768, Longitude: -89.57321
# Record added - Message Type: MSG3, Aircraft: A0F57E, Altitude: 45000, Latitude: 38.61887, Longitude: -90.12646
# Record added - Message Type: MSG4, Aircraft: A68336, Speed: 523, Heading: 131
# Record added - Message Type: MSG4, Aircraft: C001EA, Speed: 379, Heading: 315
# Record added - Message Type: MSG4, Aircraft: A0F57E, Speed: 551, Heading: 131
# Record added - Message Type: MSG3, Aircraft: A262AD, Altitude: 37000, Latitude: 38.69119, Longitude: -90.15851
# Record added - Message Type: MSG4, Aircraft: A262AD, Speed: 495, Heading: 111
# Record added - Message Type: MSG3, Aircraft: C001EA, Altitude: 43000, Latitude: 38.83484, Longitude: -90.14366
# Record added - Message Type: MSG3, Aircraft: A0F57E, Altitude: 45000, Latitude: 38.48758, Longitude: -89.93492
# Record added - Message Type: MSG4, Aircraft: A0F57E, Speed: 551, Heading: 131
# Record added - Message Type: MSG3, Aircraft: A0F57E, Altitude: 45000, Latitude: 38.45368, Longitude: -89.88562
# Record added - Message Type: MSG4, Aircraft: A41CC4, Speed: 408, Heading: 311
# Record added - Message Type: MSG4, Aircraft: AA6F80, Speed: 515, Heading: 16
# Record added - Message Type: MSG3, Aircraft: A0F57E, Altitude: 45000, Latitude: 38.39559, Longitude: -89.80129
# Record added - Message Type: MSG3, Aircraft: A0F57E, Altitude: 45000, Latitude: 38.37355, Longitude: -89.76940
# Record added - Message Type: MSG4, Aircraft: A262AD, Speed: 495, Heading: 111
# Record added - Message Type: MSG4, Aircraft: A41CC4, Speed: 395, Heading: 311
# Record added - Message Type: MSG3, Aircraft: A2A1E3, Altitude: 2900, Latitude: 38.56165, Longitude: -90.02764
# Record added - Message Type: MSG4, Aircraft: A262AD, Speed: 495, Heading: 111
# Record added - Message Type: MSG4, Aircraft: A2A1E3, Speed: 152, Heading: 35
# Record added - Message Type: MSG3, Aircraft: AA6F80, Altitude: 33000, Latitude: 38.37946, Longitude: -89.97925
# Record added - Message Type: MSG4, Aircraft: A41CC4, Speed: 399, Heading: 311
# Record added - Message Type: MSG3, Aircraft: AA6F80, Altitude: 33000, Latitude: 38.42654, Longitude: -89.96204
# Record added - Message Type: MSG3, Aircraft: A2A1E3, Altitude: 3475, Latitude: 38.59199, Longitude: -90.00116
# Record added - Message Type: MSG4, Aircraft: AA6F80, Speed: 515, Heading: 16
# Record added - Message Type: MSG3, Aircraft: AC2038, Altitude: 9075, Latitude: 38.37338, Longitude: -89.99224
# Record added - Message Type: MSG4, Aircraft: AC2038, Speed: 279, Heading: 340
# Record added - Message Type: MSG4, Aircraft: AC2038, Speed: 279, Heading: 340
# Record added - Message Type: MSG3, Aircraft: AC2038, Altitude: 7500, Latitude: 38.42519, Longitude: -90.01520
# Record added - Message Type: MSG3, Aircraft: AC2038, Altitude: 7475, Latitude: 38.42589, Longitude: -90.01550
# Record added - Message Type: MSG3, Aircraft: AC2038, Altitude: 6800, Latitude: 38.45045, Longitude: -90.02645
# Record added - Message Type: MSG3, Aircraft: AC2038, Altitude: 6425, Latitude: 38.46419, Longitude: -90.03260
# Record added - Message Type: MSG3, Aircraft: AC2038, Altitude: 6100, Latitude: 38.47724, Longitude: -90.03845
# Record added - Message Type: MSG4, Aircraft: AC2038, Speed: 285, Heading: 341
# Record added - Message Type: MSG3, Aircraft: AC2038, Altitude: 5850, Latitude: 38.49139, Longitude: -90.04474
# Record added - Message Type: MSG4, Aircraft: AC2038, Speed: 280, Heading: 340
# Record added - Message Type: MSG3, Aircraft: AC2038, Altitude: 5250, Latitude: 38.54132, Longitude: -90.06723
# Record added - Message Type: MSG4, Aircraft: AC2038, Speed: 279, Heading: 341
# Record added - Message Type: MSG3, Aircraft: AC2038, Altitude: 4950, Latitude: 38.56308, Longitude: -90.07697
# Record added - Message Type: MSG4, Aircraft: AC2038, Speed: 276, Heading: 341
# Record added - Message Type: MSG3, Aircraft: A3ECC8, Altitude: 34025, Latitude: , Longitude:
# Record added - Message Type: MSG3, Aircraft: A3ECC8, Altitude: 34025, Latitude: 38.85538, Longitude: -89.94971
# Record added - Message Type: MSG4, Aircraft: AC2038, Speed: 267, Heading: 338
# Record added - Message Type: MSG3, Aircraft: A3ECC8, Altitude: 34025, Latitude: 38.85690, Longitude: -90.08126
# Record added - Message Type: MSG4, Aircraft: A62863, Speed: 343, Heading: 338
# Record added - Message Type: MSG4, Aircraft: A62863, Speed: 341, Heading: 345
# Record added - Message Type: MSG4, Aircraft: A62863, Speed: 341, Heading: 346
# Record added - Message Type: MSG4, Aircraft: A62863, Speed: 340, Heading: 350
# Record added - Message Type: MSG4, Aircraft: A62863, Speed: 324, Heading: 355
# Record added - Message Type: MSG4, Aircraft: A62863, Speed: 324, Heading: 355
# Record added - Message Type: MSG3, Aircraft: A62863, Altitude: 10100, Latitude: , Longitude:
# Record added - Message Type: MSG4, Aircraft: A62863, Speed: 300, Heading: 355
# Record added - Message Type: MSG4, Aircraft: A62863, Speed: 272, Heading: 355
# Record added - Message Type: MSG4, Aircraft: A62863, Speed: 281, Heading: 355
# Record added - Message Type: MSG3, Aircraft: A62863, Altitude: 7075, Latitude: 38.42757, Longitude: -90.10132
# Record added - Message Type: MSG4, Aircraft: A62863, Speed: 297, Heading: 358
# Record added - Message Type: MSG4, Aircraft: A62863, Speed: 298, Heading: 358
# Record added - Message Type: MSG4, Aircraft: A62863, Speed: 299, Heading: 358
# Record added - Message Type: MSG3, Aircraft: ABB995, Altitude: 18000, Latitude: 38.56883, Longitude: -90.09918
# Record added - Message Type: MSG4, Aircraft: ABB995, Speed: 396, Heading: 103
# Record added - Message Type: MSG4, Aircraft: ABB995, Speed: 400, Heading: 106
# Record added - Message Type: MSG3, Aircraft: ABB995, Altitude: 19175, Latitude: 38.55258, Longitude: -90.02932
# Record added - Message Type: MSG4, Aircraft: ABB995, Speed: 391, Heading: 119
# Record added - Message Type: MSG3, Aircraft: ABB995, Altitude: 19600, Latitude: 38.54256, Longitude: -90.00985
# Record added - Message Type: MSG3, Aircraft: ABB995, Altitude: 20475, Latitude: 38.51849, Longitude: -89.97583
# Record added - Message Type: MSG3, Aircraft: ABB995, Altitude: 20525, Latitude: 38.51737, Longitude: -89.97430
# Record added - Message Type: MSG4, Aircraft: ABB995, Speed: 386, Heading: 132
# Record added - Message Type: MSG3, Aircraft: ABB995, Altitude: 21350, Latitude: 38.49246, Longitude: -89.93958
# Record added - Message Type: MSG3, Aircraft: ABB995, Altitude: 21700, Latitude: 38.48145, Longitude: -89.92375
# Record added - Message Type: MSG4, Aircraft: ABB995, Speed: 393, Heading: 131
# Record added - Message Type: MSG4, Aircraft: ABB995, Speed: 393, Heading: 131
# Record added - Message Type: MSG4, Aircraft: ABB995, Speed: 397, Heading: 131
# Record added - Message Type: MSG4, Aircraft: ABB995, Speed: 399, Heading: 131
# Record added - Message Type: MSG4, Aircraft: ABB995, Speed: 402, Heading: 131
# Record added - Message Type: MSG4, Aircraft: ABB995, Speed: 403, Heading: 131
# Record added - Message Type: MSG4, Aircraft: ABB995, Speed: 405, Heading: 131
# Record added - Message Type: MSG3, Aircraft: ABB995, Altitude: 24625, Latitude: 38.37822, Longitude: -89.77209
# Record added - Message Type: MSG3, Aircraft: ABB995, Altitude: 25300, Latitude: 38.35121, Longitude: -89.73352
# Record added - Message Type: MSG3, Aircraft: ADD2B5, Altitude: 5325, Latitude: 38.70083, Longitude: -89.96735
# Record added - Message Type: MSG4, Aircraft: A22B2F, Speed: 417, Heading: 311
# Record added - Message Type: MSG4, Aircraft: A22B2F, Speed: 417, Heading: 311
# Record added - Message Type: MSG4, Aircraft: A22B2F, Speed: 417, Heading: 311
# Record added - Message Type: MSG3, Aircraft: ADD2B5, Altitude: 4775, Latitude: 38.67284, Longitude: -89.99182
# Record added - Message Type: MSG4, Aircraft: ADD2B5, Speed: 204, Heading: 212
# Record added - Message Type: MSG3, Aircraft: A22B2F, Altitude: 36000, Latitude: 38.25618, Longitude: -89.59947
# Record added - Message Type: MSG4, Aircraft: ADD2B5, Speed: 202, Heading: 213
# Record added - Message Type: MSG4, Aircraft: ADD2B5, Speed: 206, Heading: 230
# Record added - Message Type: MSG3, Aircraft: ADD2B5, Altitude: 3800, Latitude: 38.62354, Longitude: -90.04299
# Record added - Message Type: MSG4, Aircraft: ADD2B5, Speed: 214, Heading: 272
# Record added - Message Type: MSG4, Aircraft: ADD2B5, Speed: 214, Heading: 273
# Record added - Message Type: MSG3, Aircraft: A22B2F, Altitude: 36000, Latitude: 38.35364, Longitude: -89.74019
# Record added - Message Type: MSG3, Aircraft: AAF960, Altitude: 37000, Latitude: , Longitude:
# Record added - Message Type: MSG4, Aircraft: A22B2F, Speed: 424, Heading: 311
# Record added - Message Type: MSG3, Aircraft: A22B2F, Altitude: 36025, Latitude: 38.40431, Longitude: -89.81358
# Record added - Message Type: MSG4, Aircraft: A22B2F, Speed: 424, Heading: 311
# Record added - Message Type: MSG3, Aircraft: A22B2F, Altitude: 36025, Latitude: 38.43069, Longitude: -89.85187
# Record added - Message Type: MSG3, Aircraft: A22B2F, Altitude: 36000, Latitude: 38.44450, Longitude: -89.87199
# Record added - Message Type: MSG3, Aircraft: A22B2F, Altitude: 36025, Latitude: 38.45778, Longitude: -89.89127
# Record added - Message Type: MSG3, Aircraft: A22B2F, Altitude: 36025, Latitude: 38.45895, Longitude: -89.89294
# Record added - Message Type: MSG3, Aircraft: A22B2F, Altitude: 36025, Latitude: 38.48618, Longitude: -89.93250
# Record added - Message Type: MSG4, Aircraft: A22B2F, Speed: 423, Heading: 311
# Record added - Message Type: MSG3, Aircraft: A22B2F, Altitude: 36025, Latitude: 38.49902, Longitude: -89.95122
# Record added - Message Type: MSG3, Aircraft: A22B2F, Altitude: 36025, Latitude: 38.51178, Longitude: -89.96973
# ...
# Socket timeout, waiting for data...
# Restarting socket
# Record added - Message Type: MSG4, Aircraft: AA649C, Speed: 571, Heading: 66
# Record added - Message Type: MSG4, Aircraft: AA649C, Speed: 571, Heading: 66
# Record added - Message Type: MSG3, Aircraft: AA649C, Altitude: 39000, Latitude: 38.61471, Longitude: -90.01050
# Record added - Message Type: MSG4, Aircraft: AA649C, Speed: 571, Heading: 66
# Record added - Message Type: MSG4, Aircraft: AA649C, Speed: 571, Heading: 66
# Record added - Message Type: MSG4, Aircraft: AA649C, Speed: 571, Heading: 66
# Record added - Message Type: MSG3, Aircraft: AA649C, Altitude: 39000, Latitude: 38.65000, Longitude: -89.90955
# Record added - Message Type: MSG4, Aircraft: AA649C, Speed: 573, Heading: 66
# Record added - Message Type: MSG3, Aircraft: AA649C, Altitude: 39000, Latitude: 38.68465, Longitude: -89.81019
# Record added - Message Type: MSG4, Aircraft: AA649C, Speed: 573, Heading: 66
# Record added - Message Type: MSG4, Aircraft: AA649C, Speed: 572, Heading: 66
# Record added - Message Type: MSG3, Aircraft: AB4383, Altitude: 2550, Latitude: , Longitude:
# Record added - Message Type: MSG4, Aircraft: AB4383, Speed: 245, Heading: 234
# Record added - Message Type: MSG3, Aircraft: A2D6A9, Altitude: 34000, Latitude: , Longitude:
# Record added - Message Type: MSG4, Aircraft: AA1A1F, Speed: 384, Heading: 263
# Record added - Message Type: MSG4, Aircraft: AA1A1F, Speed: 384, Heading: 262
# Record added - Message Type: MSG3, Aircraft: AA1A1F, Altitude: 32000, Latitude: 38.70009, Longitude: -89.75049
# Record added - Message Type: MSG4, Aircraft: C07EF2, Speed: 432, Heading: 339
# Record added - Message Type: MSG4, Aircraft: C07EF2, Speed: 432, Heading: 339
# Record added - Message Type: MSG3, Aircraft: C07EF2, Altitude: 38000, Latitude: 38.43292, Longitude: -90.03778
# Record added - Message Type: MSG4, Aircraft: ABDAA4, Speed: 520, Heading: 131
# Record added - Message Type: MSG3, Aircraft: C07EF2, Altitude: 38000, Latitude: 38.45345, Longitude: -90.04761
# Record added - Message Type: MSG4, Aircraft: C07EF2, Speed: 431, Heading: 339
# Record added - Message Type: MSG4, Aircraft: ABDAA4, Speed: 519, Heading: 131
# Record added - Message Type: MSG3, Aircraft: ABDAA4, Altitude: 33000, Latitude: , Longitude:
# Record added - Message Type: MSG3, Aircraft: C07EF2, Altitude: 38000, Latitude: 38.54968, Longitude: -90.09375
# Record added - Message Type: MSG3, Aircraft: C07EF2, Altitude: 38000, Latitude: 38.56965, Longitude: -90.10339
# Record added - Message Type: MSG4, Aircraft: ABDAA4, Speed: 520, Heading: 131
# Record added - Message Type: MSG3, Aircraft: ABDAA4, Altitude: 33000, Latitude: 38.53580, Longitude: -90.00482
# Record added - Message Type: MSG4, Aircraft: ABDAA4, Speed: 521, Heading: 131
# Record added - Message Type: MSG4, Aircraft: ABDAA4, Speed: 522, Heading: 131
# Record added - Message Type: MSG3, Aircraft: C07EF2, Altitude: 38000, Latitude: 38.66945, Longitude: -90.15172
# Record added - Message Type: MSG3, Aircraft: ABDAA4, Altitude: 33000, Latitude: 38.45443, Longitude: -89.88666
# Record added - Message Type: MSG4, Aircraft: C07EF2, Speed: 428, Heading: 339
# Record added - Message Type: MSG4, Aircraft: ABDAA4, Speed: 522, Heading: 131
# Record added - Message Type: MSG3, Aircraft: ABDAA4, Altitude: 33000, Latitude: 38.42198, Longitude: -89.83950
# Record added - Message Type: MSG4, Aircraft: ABDAA4, Speed: 523, Heading: 131
# Record added - Message Type: MSG3, Aircraft: ABDAA4, Altitude: 33000, Latitude: 38.39061, Longitude: -89.79395
# Record added - Message Type: MSG4, Aircraft: ABDAA4, Speed: 523, Heading: 131
# Record added - Message Type: MSG4, Aircraft: ABDAA4, Speed: 523, Heading: 131
# Record added - Message Type: MSG3, Aircraft: ABDAA4, Altitude: 33000, Latitude: 38.31752, Longitude: -89.68814
# Record added - Message Type: MSG3, Aircraft: ABDAA4, Altitude: 33000, Latitude: 38.31463, Longitude: -89.68402
# Record added - Message Type: MSG4, Aircraft: ABDAA4, Speed: 522, Heading: 131
# Record added - Message Type: MSG4, Aircraft: ABDAA4, Speed: 522, Heading: 131
# Record added - Message Type: MSG3, Aircraft: ABDAA4, Altitude: 33000, Latitude: 38.19527, Longitude: -89.51212
# Record added - Message Type: MSG4, Aircraft: A7FE27, Speed: 286, Heading: 345
# Record added - Message Type: MSG3, Aircraft: A7FE27, Altitude: 8650, Latitude: , Longitude:
# Socket timeout, waiting for data...
# Restarting socket
# Exiting the program.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
